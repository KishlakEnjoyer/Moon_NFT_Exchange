# %% [markdown]
# # 1. Import libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import math
import random
import json
import os
import re
from datetime import datetime
from pathlib import Path
from PIL import Image, ImageDraw

# %% [markdown]
# # 2. Collections parsing

# %%
# url of site for parsing
url = "https://telegifter.ru/gifts/collections/"

# %%
# Check access
pages = requests.get(url) # подключаемся
soup = bs(pages.text, 'html.parser') # определеяем
print(pages.status_code)
# Out:
# 200

# %% [markdown]
# Nice, we can to parse this site!

# %%
# Result list for dataframe in future
result_list_collection = { 
    "collection_id": [],
    "collection_name": [],
    "collection_image_url": [],
    "collection_limit": [],
    "collection_base_price": []
}

# %%
collection_container = soup.find('div', class_='container-575')
collection_cards = collection_container.find_all('div', class_='mini-single')

print(f'📦 Found elements: {len(collection_cards)}')
# Out:
# 📦 Found elements: 144

# %%
images_folder = 'images/collections'

if not os.path.exists(images_folder):
    os.makedirs(images_folder)
    print(f'✅ Folder created: {images_folder}')
else:
    print(f'📂 Folder is already exist: {images_folder}')
# Out:
# 📂 Folder is already exist: images/collections

# %%
def download_image(url, folder, filename):
    try:
        # Get image
        img_data = requests.get(url).content
        
        # Determine file type
        if '.webp' in url:
            ext = '.webp'
        elif '.png' in url:
            ext = '.png'
        elif '.jpg' in url or '.jpeg' in url:
            ext = '.jpg'
        elif '.svg' in url:
            ext = '.svg'
        else:
            ext = '.webp' 
        
        # Full path
        filepath = os.path.join(folder, filename + ext)
        
        # Check exist
        if os.path.exists(filepath):
            print(f'⏭️ Skipped (Already exist): {filename}{ext}')
            return filepath
        
        # Save
        with open(filepath, 'wb') as handler:
            handler.write(img_data)
        
        print(f'✅ Downloaded: {filename}{ext}')
        return filepath
        
    except Exception as e:
        print(f'❌ Error {url}: {e}')
        return None

# %%
i = 0

# %time
for card in collection_cards:
    present_title = card.find('div', class_='mini-single-title-gifts').text.strip()
    
    check = card.find('div', class_='mini-single-stars col').text.strip().split()[0]
    check2 = card.find('div', class_='mini-single-other col').text.strip().split()[1]
    
    if check == 'Pre-market' or check2 == '∞':
        print(f'{present_title} skip!')
        continue
    link = card.find('a')
    if not link or not link.get('href'):
        continue
    collection_url = link.get('href')

    collection_page = requests.get(collection_url)
    collection_soup = bs(collection_page.text, 'html.parser')

    time.sleep(1)

    try:
        present_count = int(collection_soup.find_all('div', class_='col-sm-6 col-xs-12 stat-table-info')[2].text.strip().replace(' ', ''))
    except:
        present_count = int(collection_soup.find_all('div', class_='col-sm-6 col-xs-12 stat-table-info')[3].text.strip().replace(' ', ''))
    
    try:
        present_price = math.ceil(float(collection_soup.find_all('div', class_='col-sm-6 col-xs-12 stat-table-info')[5].text.strip().split()[2]))
    except:
        try:
            present_price = math.ceil(float(collection_soup.find_all('div', class_='col-sm-6 col-xs-12 stat-table-info')[-1].text.strip().split()[2]))
        except:
            present_price = math.ceil(float(collection_soup.find_all('div', class_='col-sm-6 col-xs-12 stat-table-info')[6].text.strip().split()[2]))
            
            
    try:
        img_elem = collection_soup.find('div', class_='wp-block-image').find('img')
        if img_elem and img_elem.get('src'):
            img_url = img_elem.get('src')
            
            # Make full url
            if not img_url.startswith('http'):
                img_url = 'https://telegifter.ru' + img_url
            
            # Generate file name
            # Desk Calendar → desk_calendar
            filename = re.sub(r'[^a-zA-Z0-9]', '_', present_title).lower().strip('_')
            
            # Download to folder
            download_image(img_url, images_folder, filename)
        else:
            print(f'⚠️ No image for {present_title}')
            
    except Exception as e:
        print(f'⚠️ Error {present_title}: {e}')

    result_list_collection['collection_id'].append(i)
    result_list_collection['collection_name'].append(present_title)
    result_list_collection['collection_image_url'].append(filename)
    result_list_collection['collection_limit'].append(present_count)
    result_list_collection['collection_base_price'].append(present_price)
    
    print(f'{i} - {present_title} - {present_count} pieces - {present_price} TON')
    i += 1
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 1 May skip!
# ✅ Downloaded: artisan_brick.webp
# 0 - Artisan Brick - 7000 pieces - 20 TON
# ✅ Downloaded: astral_shard.webp
# 1 - Astral Shard - 10000 pieces - 2 TON
# ✅ Downloaded: b_day_candle.webp
# 2 - B-day Candle - 500000 pieces - 2 TON
# ✅ Downloaded: berry_box.webp
# 3 - Berry Box - 100000 pieces - 1 TON
# ✅ Downloaded: big_year.webp
# 4 - Big Year - 200000 pieces - 1 TON
# ✅ Downloaded: bling_binky.webp
# 5 - Bling Binky - 10000 pieces - 25 TON
# ✅ Downloaded: bonded_ring.webp
# 6 - Bonded Ring - 9000 pieces - 21 TON
# Book skip!
# ✅ Downloaded: bow_tie.webp
# 7 - Bow Tie - 100000 pieces - 2 TON
# ✅ Downloaded: bunny_muffin.webp
# 8 - Bunny Muffin - 100000 pieces - 1 TON
# Candle Lamp skip!
# ✅ Downloaded: candy_cane.webp
# 9 - Candy Cane - 600000 pieces - 1 TON
# Case skip!
# Christmas Tree skip!
# ✅ Downloaded: clover_pin.webp
# 10 - Clover Pin - 300000 pieces - 1 TON
# Coconut skip!
# Coffin skip!
# ✅ Downloaded: cookie_heart.webp
# 11 - Cookie Heart - 400000 pieces - 1 TON
# ✅ Downloaded: crystal_ball.webp
# 12 - Crystal Ball - 30000 pieces - 1 TON
# ✅ Downloaded: cupid_charm.webp
# 13 - Cupid Charm - 40000 pieces - 3 TON
# ✅ Downloaded: desk_calendar.webp
# 14 - Desk Calendar - 500000 pieces - 1 TON
# ✅ Downloaded: diamond_ring.webp
# 15 - Diamond Ring - 35000 pieces - 5 TON
# Dove of Peace skip!
# Durov's Boots skip!
# ✅ Downloaded: durov_s_cap.webp
# 16 - Durov's Cap - 5000 pieces - 3 TON
# Durov's Coat skip!
# Durov's Figurine skip!
# Durov's Sunglasses skip!
# Easter Cake skip!
# ✅ Downloaded: easter_egg.webp
# 17 - Easter Egg - 180000 pieces - 2 TON
# ✅ Downloaded: electric_skull.webp
# 18 - Electric Skull - 10000 pieces - 1 TON
# ✅ Downloaded: eternal_candle.webp
# 19 - Eternal Candle - 50000 pieces - 1 TON
# ✅ Downloaded: eternal_rose.webp
# 20 - Eternal Rose - 50000 pieces - 1 TON
# ✅ Downloaded: evil_eye.webp
# 21 - Evil Eye - 120000 pieces - 1 TON
# ✅ Downloaded: faith_amulet.webp
# 22 - Faith Amulet - 200000 pieces - 1 TON
# ✅ Downloaded: flying_broom.webp
# 23 - Flying Broom - 30000 pieces - 1 TON
# ✅ Downloaded: fresh_socks.webp
# 24 - Fresh Socks - 250000 pieces - 1 TON
# ✅ Downloaded: gem_signet.webp
# 25 - Gem Signet - 10000 pieces - 2 TON
# ✅ Downloaded: genie_lamp.webp
# 26 - Genie Lamp - 15000 pieces - 1 TON
# ✅ Downloaded: ginger_cookie.webp
# 27 - Ginger Cookie - 300000 pieces - 1 TON
# Gravestone skip!
# ✅ Downloaded: hanging_star.webp
# 28 - Hanging Star - 100000 pieces - 1 TON
# ✅ Downloaded: happy_brownie.webp
# 29 - Happy Brownie - 300000 pieces - 1 TON
# ✅ Downloaded: heart_locket.webp
# 30 - Heart Locket - 2000 pieces - 41 TON
# ✅ Downloaded: heroic_helmet.webp
# 31 - Heroic Helmet - 8000 pieces - 21 TON
# ✅ Downloaded: hex_pot.webp
# 32 - Hex Pot - 120000 pieces - 1 TON
# ✅ Downloaded: holiday_drink.webp
# 33 - Holiday Drink - 200000 pieces - 1 TON
# ✅ Downloaded: homemade_cake.webp
# 34 - Homemade Cake - 500000 pieces - 2 TON
# ✅ Downloaded: hypno_lollipop.webp
# 35 - Hypno Lollipop - 300000 pieces - 1 TON
# I love you skip!
# ✅ Downloaded: ice_cream.webp
# 36 - Ice Cream - 350000 pieces - 1 TON
# Ice Cream Cone skip!
# Ice Cream Scoops skip!
# ✅ Downloaded: input_key.webp
# 37 - Input Key - 200000 pieces - 1 TON
# ✅ Downloaded: instant_ramen.webp
# 38 - Instant Ramen - 500000 pieces - 1 TON
# ✅ Downloaded: ion_gem.webp
# 39 - Ion Gem - 5000 pieces - 1 TON
# ✅ Downloaded: ionic_dryer.webp
# 40 - Ionic Dryer - 40000 pieces - 6 TON
# Irish Bear skip!
# ✅ Downloaded: jack_in_the_box.webp
# 41 - Jack in the Box - 100000 pieces - 2 TON
# ✅ Downloaded: jelly_bunny.webp
# 42 - Jelly Bunny - 200000 pieces - 1 TON
# ✅ Downloaded: jester_hat.webp
# 43 - Jester Hat - 400000 pieces - 1 TON
# ✅ Downloaded: jingle_bells.webp
# 44 - Jingle Bells - 200000 pieces - 1 TON
# ✅ Downloaded: jolly_chimp.webp
# 45 - Jolly Chimp - 150000 pieces - 1 TON
# ✅ Downloaded: joyful_bundle.webp
# 46 - Joyful Bundle - 150000 pieces - 2 TON
# ✅ Downloaded: khabib_s_papakha.webp
# 47 - Khabib's Papakha - 29000 pieces - 105 TON
# ✅ Downloaded: kissed_frog.webp
# 48 - Kissed Frog - 15000 pieces - 1 TON
# Kitty Medallion skip!
# ✅ Downloaded: light_sword.webp
# 49 - Light Sword - 150000 pieces - 1 TON
# ✅ Downloaded: lol_pop.webp
# 50 - Lol Pop - 500000 pieces - 1 TON
# ✅ Downloaded: loot_bag.webp
# 51 - Loot Bag - 15000 pieces - 11 TON
# ✅ Downloaded: love_candle.webp
# 52 - Love Candle - 50000 pieces - 1 TON
# ✅ Downloaded: love_potion.webp
# 53 - Love Potion - 35000 pieces - 5 TON
# ✅ Downloaded: low_rider.webp
# 54 - Low Rider - 24000 pieces - 29 TON
# ✅ Downloaded: lunar_snake.webp
# 55 - Lunar Snake - 400000 pieces - 1 TON
# ✅ Downloaded: lush_bouquet.webp
# 56 - Lush Bouquet - 180000 pieces - 2 TON
# ✅ Downloaded: mad_pumpkin.webp
# 57 - Mad Pumpkin - 30000 pieces - 1 TON
# ✅ Downloaded: magic_potion.webp
# 58 - Magic Potion - 5000 pieces - 1 TON
# Mask skip!
# ✅ Downloaded: mighty_arm.webp
# 59 - Mighty Arm - 5000 pieces - 43 TON
# ✅ Downloaded: mini_oscar.webp
# 60 - Mini Oscar - 10000 pieces - 2 TON
# ✅ Downloaded: money_pot.webp
# 61 - Money Pot - 120000 pieces - 2 TON
# ✅ Downloaded: mood_pack.webp
# 62 - Mood Pack - 200000 pieces - 3 TON
# ✅ Downloaded: moon_pendant.webp
# 63 - Moon Pendant - 120000 pieces - 1 TON
# ✅ Downloaded: mousse_cake.webp
# 64 - Mousse Cake - 250000 pieces - 1 TON
# ✅ Downloaded: nail_bracelet.webp
# 65 - Nail Bracelet - 5000 pieces - 41 TON
# ✅ Downloaded: neko_helmet.webp
# 66 - Neko Helmet - 18000 pieces - 14 TON
# New Year's Bear skip!
# ✅ Downloaded: party_sparkler.webp
# 67 - Party Sparkler - 400000 pieces - 1 TON
# Pen skip!
# ✅ Downloaded: perfume_bottle.webp
# 68 - Perfume Bottle - 10000 pieces - 2 TON
# ✅ Downloaded: pet_snake.webp
# 69 - Pet Snake - 400000 pieces - 1 TON
# Pink Bear skip!
# ✅ Downloaded: plush_pepe.webp
# 70 - Plush Pepe - 3000 pieces - 5 TON
# Polar Bear skip!
# ✅ Downloaded: pool_float.webp
# 71 - Pool Float - 250000 pieces - 2 TON
# ✅ Downloaded: precious_peach.webp
# 72 - Precious Peach - 5000 pieces - 3 TON
# ✅ Downloaded: pretty_posy.webp
# 73 - Pretty Posy - 200000 pieces - 1 TON
# ✅ Downloaded: rare_bird.webp
# 74 - Rare Bird - 15000 pieces - 28 TON
# ✅ Downloaded: record_player.webp
# 75 - Record Player - 50000 pieces - 1 TON
# Red Star skip!
# Resistance Dog skip!
# ✅ Downloaded: restless_jar.webp
# 76 - Restless Jar - 150000 pieces - 1 TON
# Roses skip!
# ✅ Downloaded: sakura_flower.webp
# 77 - Sakura Flower - 100000 pieces - 1 TON
# Sandcastle skip!
# ✅ Downloaded: santa_hat.webp
# 78 - Santa Hat - 150000 pieces - 1 TON
# ✅ Downloaded: scared_cat.webp
# 79 - Scared Cat - 20000 pieces - 1 TON
# ✅ Downloaded: sharp_tongue.webp
# 80 - Sharp Tongue - 10000 pieces - 1 TON
# ✅ Downloaded: signet_ring.webp
# 81 - Signet Ring - 30000 pieces - 1 TON
# ✅ Downloaded: skull_flower.webp
# 82 - Skull Flower - 30000 pieces - 1 TON
# ✅ Downloaded: sky_stilettos.webp
# 83 - Sky Stilettos - 70000 pieces - 2 TON
# ✅ Downloaded: sleigh_bell.webp
# 84 - Sleigh Bell - 50000 pieces - 1 TON
# ✅ Downloaded: snake_box.webp
# 85 - Snake Box - 400000 pieces - 1 TON
# ✅ Downloaded: snoop_cigar.webp
# 86 - Snoop Cigar - 120000 pieces - 6 TON
# ✅ Downloaded: snoop_dogg.webp
# 87 - Snoop Dogg - 600000 pieces - 2 TON
# ✅ Downloaded: snow_globe.webp
# 88 - Snow Globe - 120000 pieces - 1 TON
# ✅ Downloaded: snow_mittens.webp
# 89 - Snow Mittens - 90000 pieces - 1 TON
# ✅ Downloaded: spiced_wine.webp
# 90 - Spiced Wine - 400000 pieces - 1 TON
# ✅ Downloaded: spring_basket.webp
# 91 - Spring Basket - 250000 pieces - 1 TON
# ✅ Downloaded: spy_agaric.webp
# 92 - Spy Agaric - 100000 pieces - 1 TON
# ✅ Downloaded: star_notepad.webp
# 93 - Star Notepad - 200000 pieces - 1 TON
# Statue of Liberty skip!
# ✅ Downloaded: stellar_rocket.webp
# 94 - Stellar Rocket - 180000 pieces - 2 TON
# Surfboard skip!
# ✅ Downloaded: swag_bag.webp
# 95 - Swag Bag - 240000 pieces - 3 TON
# ✅ Downloaded: swiss_watch.webp
# 96 - Swiss Watch - 50000 pieces - 1 TON
# ✅ Downloaded: tama_gadget.webp
# 97 - Tama Gadget - 200000 pieces - 1 TON
# Telegram Pin skip!
# ✅ Downloaded: top_hat.webp
# 98 - Top Hat - 40000 pieces - 5 TON
# Torch of Freedom skip!
# ✅ Downloaded: toy_bear.webp
# 99 - Toy Bear - 60000 pieces - 2 TON
# ✅ Downloaded: trapped_heart.webp
# 100 - Trapped Heart - 30000 pieces - 1 TON
# Trojan Horse skip!
# ✅ Downloaded: ufc_strike.webp
# 101 - UFC Strike - 60000 pieces - 38 TON
# ✅ Downloaded: valentine_box.webp
# 102 - Valentine Box - 50000 pieces - 2 TON
# ✅ Downloaded: victory_medal.webp
# 103 - Victory Medal - 150000 pieces - 2 TON
# ✅ Downloaded: vintage_cigar.webp
# 104 - Vintage Cigar - 50000 pieces - 1 TON
# ✅ Downloaded: voodoo_doll.webp
# 105 - Voodoo Doll - 30000 pieces - 1 TON
# ✅ Downloaded: westside_sign.webp
# 106 - Westside Sign - 12000 pieces - 57 TON
# ✅ Downloaded: whip_cupcake.webp
# 107 - Whip Cupcake - 400000 pieces - 1 TON
# ✅ Downloaded: winter_wreath.webp
# 108 - Winter Wreath - 200000 pieces - 1 TON
# ✅ Downloaded: witch_hat.webp
# 109 - Witch Hat - 100000 pieces - 1 TON
# ✅ Downloaded: xmas_stocking.webp
# 110 - Xmas Stocking - 600000 pieces - 1 TON

# %% [markdown]
# # 3. Parsing symbols

# %%
# url of site for parsing
url = "https://telegifter.ru/gifts/rarest-symbol/"

# %%
# Check access
pages = requests.get(url) # подключаемся
soup = bs(pages.text, 'html.parser') # определеяем
print(pages.status_code)
# Out:
# 200

# %%
# Result list for dataframe in future
result_list_symbol = { 
    "symbol_id": [],
    "symbol_name": [],
    "symbol_image_url": []
}

# %%
symbol_container = soup.find('div', class_='gifts-table-rare active container')
symbol_cards = symbol_container.find_all('div', class_='row gift-item')

print(f'📦 Found elements: {len(symbol_cards)}')
# Out:
# 📦 Found elements: 718

# %%
images_folder = 'images/symbols'

if not os.path.exists(images_folder):
    os.makedirs(images_folder)
    print(f'✅ Folder created: {images_folder}')
else:
    print(f'📂 Folder is already exist: {images_folder}')
# Out:
# 📂 Folder is already exist: images/symbols

# %%
i = 0

# %time
for card in symbol_cards:
    symbol_title = card.find_all('div', class_='col-sm-3 col-xs-6')[1].text.strip()
    
    try:
        img_elem = card.find_all('div', class_='col-sm-3 col-xs-6')[0].find('img')
        if img_elem and img_elem.get('src'):
            img_url = img_elem.get('src')
            
            # Make full url
            if not img_url.startswith('http'):
                img_url = 'https://telegifter.ru' + img_url
            
            # Generate file name
            # Desk Calendar → desk_calendar
            filename = re.sub(r'[^a-zA-Z0-9]', '_', symbol_title).lower().strip('_')
            
            # Download to folder
            download_image(img_url, images_folder, filename)
            
            result_list_symbol['symbol_id'].append(i)
            result_list_symbol['symbol_name'].append(symbol_title)
            result_list_symbol['symbol_image_url'].append(filename)
            
            print(f"{symbol_title} added!")
            i += 1
        else:
            print(f'⚠️ No image for {symbol_title}')
            
    except Exception as e:
        print(f'⚠️ Error {symbol_title}: {e}')
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# ⏭️ Skipped (Already exist): old_scull.webp
# Old Scull added!
# ⏭️ Skipped (Already exist): witch_hat.webp
# Witch Hat added!
# ⏭️ Skipped (Already exist): tarot_cards.webp
# Tarot Cards added!
# ⏭️ Skipped (Already exist): casket.webp
# Casket added!
# ⏭️ Skipped (Already exist): voodoo.webp
# Voodoo added!
# ⏭️ Skipped (Already exist): vampire_bat.webp
# Vampire Bat added!
# ⏭️ Skipped (Already exist): jack_o_lantern.webp
# Jack-O-Lantern added!
# ⏭️ Skipped (Already exist): tombstone.webp
# Tombstone added!
# ⏭️ Skipped (Already exist): mortar.webp
# Mortar added!
# ⏭️ Skipped (Already exist): hex_pot.webp
# Hex Pot added!
# ⏭️ Skipped (Already exist): creepy_eye.webp
# Creepy Eye added!
# ✅ Downloaded: magic_elixir.webp
# Magic Elixir added!
# ✅ Downloaded: zombie_hand.webp
# Zombie Hand added!
# ✅ Downloaded: haunted_house.webp
# Haunted House added!
# ✅ Downloaded: squeeze_bottle.webp
# Squeeze Bottle added!
# ✅ Downloaded: training_helmet.webp
# Training Helmet added!
# ✅ Downloaded: rainbow.webp
# Rainbow added!
# ✅ Downloaded: dvalishvili.webp
# Dvalishvili added!
# ✅ Downloaded: round_five.webp
# Round Five added!
# ✅ Downloaded: punching_bag.webp
# Punching Bag added!
# ✅ Downloaded: ufc_belt.webp
# UFC Belt added!
# ✅ Downloaded: round_four.webp
# Round Four added!
# ✅ Downloaded: ufc_gloves.webp
# UFC Gloves added!
# ✅ Downloaded: mouthguard.webp
# Mouthguard added!
# ✅ Downloaded: round_one.webp
# Round One added!
# ✅ Downloaded: volkanovski.webp
# Volkanovski added!
# ✅ Downloaded: chimaev.webp
# Chimaev added!
# ✅ Downloaded: jones.webp
# Jones added!
# ✅ Downloaded: fight_glove.webp
# Fight Glove added!
# ✅ Downloaded: ufc_logo.webp
# UFC Logo added!
# ✅ Downloaded: strong_arm.webp
# Strong Arm added!
# ✅ Downloaded: round_three.webp
# Round Three added!
# ✅ Downloaded: round_two.webp
# Round Two added!
# ✅ Downloaded: ufc_shorts.webp
# UFC Shorts added!
# ✅ Downloaded: adesanya.webp
# Adesanya added!
# ✅ Downloaded: the_octagon.webp
# The Octagon added!
# ✅ Downloaded: pantoja.webp
# Pantoja added!
# ✅ Downloaded: topuria.webp
# Topuria added!
# ✅ Downloaded: oliveira.webp
# Oliveira added!
# ✅ Downloaded: o_malley.webp
# O’Malley added!
# ✅ Downloaded: speed_bag.webp
# Speed Bag added!
# ✅ Downloaded: pereira.webp
# Pereira added!
# ✅ Downloaded: sports_bag.webp
# Sports Bag added!
# ✅ Downloaded: snoop_leaf.webp
# Snoop Leaf added!
# ✅ Downloaded: succubus.webp
# Succubus added!
# ✅ Downloaded: cupid_archer.webp
# Cupid Archer added!
# ✅ Downloaded: tongue.webp
# Tongue added!
# ✅ Downloaded: love_cherry.webp
# Love Cherry added!
# ✅ Downloaded: plumeria.webp
# Plumeria added!
# ✅ Downloaded: petunia.webp
# Petunia added!
# ✅ Downloaded: daffodil.webp
# Daffodil added!
# ✅ Downloaded: heart_glasses.webp
# Heart Glasses added!
# ✅ Downloaded: pansy.webp
# Pansy added!
# ✅ Downloaded: violet.webp
# Violet added!
# ✅ Downloaded: love_potion.webp
# Love Potion added!
# ✅ Downloaded: pussy_willow.webp
# Pussy Willow added!
# ✅ Downloaded: sunbloom.webp
# Sunbloom added!
# ✅ Downloaded: carnation.webp
# Carnation added!
# ✅ Downloaded: starflower.webp
# Starflower added!
# ✅ Downloaded: gift.webp
# Gift added!
# ✅ Downloaded: los_angeles.webp
# Los Angeles added!
# ✅ Downloaded: dandelion.webp
# Dandelion added!
# ✅ Downloaded: chrysanthe.webp
# Chrysanthe added!
# ✅ Downloaded: hearts.webp
# Hearts added!
# ✅ Downloaded: lingerie.webp
# Lingerie added!
# ✅ Downloaded: love.webp
# Love added!
# ✅ Downloaded: puffball.webp
# Puffball added!
# ✅ Downloaded: strelitzia.webp
# Strelitzia added!
# ✅ Downloaded: stilettos.webp
# Stilettos added!
# ✅ Downloaded: sweets_box.webp
# Sweets Box added!
# ✅ Downloaded: bellflower.webp
# Bellflower added!
# ✅ Downloaded: valentine.webp
# Valentine added!
# ✅ Downloaded: cupid_s_bow.webp
# Cupid’s Bow added!
# ✅ Downloaded: jasmin.webp
# Jasmin added!
# ✅ Downloaded: lotus.webp
# Lotus added!
# ✅ Downloaded: hibiscus.webp
# Hibiscus added!
# ✅ Downloaded: rabbit_mask.webp
# Rabbit Mask added!
# ✅ Downloaded: evil_pumpkin.webp
# Evil Pumpkin added!
# ✅ Downloaded: snoop_collar.webp
# Snoop Collar added!
# ✅ Downloaded: 213.webp
# 213 added!
# ✅ Downloaded: may_bells.webp
# May Bells added!
# ✅ Downloaded: rose_bud.webp
# Rose Bud added!
# ✅ Downloaded: ace_of_hearts.webp
# Ace Of Hearts added!
# ✅ Downloaded: paisley.webp
# Paisley added!
# ✅ Downloaded: bougainvillea.webp
# Bougainvillea added!
# ✅ Downloaded: mars___venus.webp
# Mars & Venus added!
# ✅ Downloaded: revolver.webp
# Revolver added!
# ✅ Downloaded: blunt.webp
# Blunt added!
# ✅ Downloaded: spray_paint.webp
# Spray Paint added!
# ✅ Downloaded: spider_lily.webp
# Spider Lily added!
# ✅ Downloaded: low_rider.webp
# Low Rider added!
# ✅ Downloaded: blooms.webp
# Blooms added!
# ✅ Downloaded: love_scene.webp
# Love Scene added!
# ✅ Downloaded: love_berry.webp
# Love Berry added!
# ✅ Downloaded: lovely_rose.webp
# Lovely Rose added!
# ✅ Downloaded: love_puzzle.webp
# Love Puzzle added!
# ✅ Downloaded: severed_hand.webp
# Severed Hand added!
# ✅ Downloaded: autumn_leaves.webp
# Autumn Leaves added!
# ✅ Downloaded: gentian.webp
# Gentian added!
# ✅ Downloaded: chocolate.webp
# Chocolate added!
# ✅ Downloaded: clematis.webp
# Clematis added!
# ✅ Downloaded: heart_lock.webp
# Heart Lock added!
# ✅ Downloaded: jaws.webp
# Jaws added!
# ✅ Downloaded: night_bats.webp
# Night Bats added!
# ✅ Downloaded: happy_smile.webp
# Happy Smile added!
# ✅ Downloaded: poppy.webp
# Poppy added!
# ✅ Downloaded: nice_ghost.webp
# Nice Ghost added!
# ✅ Downloaded: orchid.webp
# Orchid added!
# ✅ Downloaded: patched_heart.webp
# Patched Heart added!
# ✅ Downloaded: like_button.webp
# Like Button added!
# ✅ Downloaded: vinyl_record.webp
# Vinyl Record added!
# ✅ Downloaded: rap_sign.webp
# Rap Sign added!
# ✅ Downloaded: headphones.webp
# Headphones added!
# ✅ Downloaded: cauldron.webp
# Cauldron added!
# ✅ Downloaded: coffin.webp
# Coffin added!
# ✅ Downloaded: love_dove.webp
# Love Dove added!
# ✅ Downloaded: butterfly.webp
# Butterfly added!
# ✅ Downloaded: crow.webp
# Crow added!
# ✅ Downloaded: love_mug.webp
# Love Mug added!
# ✅ Downloaded: swag_bandana.webp
# Swag Bandana added!
# ✅ Downloaded: snowdrop.webp
# Snowdrop added!
# ✅ Downloaded: double_bed.webp
# Double Bed added!
# ✅ Downloaded: love_daisy.webp
# Love Daisy added!
# ✅ Downloaded: heartbeat.webp
# Heartbeat added!
# ✅ Downloaded: loudspeaker.webp
# Loudspeaker added!
# ✅ Downloaded: scarecrow.webp
# Scarecrow added!
# ✅ Downloaded: spooky_cat.webp
# Spooky Cat added!
# ✅ Downloaded: voodoo_doll.webp
# Voodoo Doll added!
# ✅ Downloaded: viper.webp
# Viper added!
# ✅ Downloaded: shiny_heart.webp
# Shiny Heart added!
# ✅ Downloaded: cute_paw.webp
# Cute Paw added!
# ✅ Downloaded: palm_trees.webp
# Palm Trees added!
# ✅ Downloaded: rose_blossom.webp
# Rose Blossom added!
# ✅ Downloaded: passion_latte.webp
# Passion Latte added!
# ✅ Downloaded: lovebirds.webp
# Lovebirds added!
# ✅ Downloaded: belladonna.webp
# Belladonna added!
# ✅ Downloaded: snoop_logo.webp
# Snoop Logo added!
# ✅ Downloaded: grim_reaper.webp
# Grim Reaper added!
# ✅ Downloaded: aubergine.webp
# Aubergine added!
# ✅ Downloaded: hip_hop.webp
# Hip-Hop added!
# ✅ Downloaded: uzi.webp
# UZI added!
# ✅ Downloaded: bong.webp
# Bong added!
# ✅ Downloaded: lovely_bra.webp
# Lovely Bra added!
# ✅ Downloaded: lovely_key.webp
# Lovely Key added!
# ✅ Downloaded: love_bulb.webp
# Love Bulb added!
# ✅ Downloaded: spellbook.webp
# Spellbook added!
# ✅ Downloaded: black_cat.webp
# Black Cat added!
# ✅ Downloaded: cyclamen.webp
# Cyclamen added!
# ✅ Downloaded: ushanka.webp
# Ushanka added!
# ✅ Downloaded: yo_sign.webp
# Yo Sign added!
# ✅ Downloaded: cash_cap.webp
# Cash Cap added!
# ✅ Downloaded: music_skull.webp
# Music Skull added!
# ✅ Downloaded: beretta.webp
# Beretta added!
# ✅ Downloaded: black_bandana.webp
# Black Bandana added!
# ✅ Downloaded: desert_eagle.webp
# Desert Eagle added!
# ✅ Downloaded: pro_headphones.webp
# Pro Headphones added!
# ✅ Downloaded: flying_witch.webp
# Flying Witch added!
# ✅ Downloaded: pigeon.webp
# Pigeon added!
# ✅ Downloaded: blossom.webp
# Blossom added!
# ✅ Downloaded: lovestruck.webp
# Lovestruck added!
# ✅ Downloaded: eyeball.webp
# Eyeball added!
# ✅ Downloaded: plume_shako.webp
# Plume Shako added!
# ✅ Downloaded: cupid.webp
# Cupid added!
# ✅ Downloaded: february_14.webp
# February 14 added!
# ✅ Downloaded: half_moon.webp
# Half Moon added!
# ✅ Downloaded: flying_heart.webp
# Flying Heart added!
# ✅ Downloaded: black_widow.webp
# Black Widow added!
# ✅ Downloaded: pixel_heart.webp
# Pixel Heart added!
# ✅ Downloaded: iris.webp
# Iris added!
# ✅ Downloaded: gravestone.webp
# Gravestone added!
# ✅ Downloaded: moai_head.webp
# Moai Head added!
# ✅ Downloaded: treats.webp
# Treats added!
# ✅ Downloaded: lollipop.webp
# Lollipop added!
# ✅ Downloaded: rabbit.webp
# Rabbit added!
# ✅ Downloaded: calla_lily.webp
# Calla Lily added!
# ✅ Downloaded: rap_mic.webp
# Rap Mic added!
# ✅ Downloaded: brass_knuckles.webp
# Brass Knuckles added!
# ✅ Downloaded: poison_drop.webp
# Poison Drop added!
# ✅ Downloaded: bloody_axe.webp
# Bloody Axe added!
# ✅ Downloaded: witch_s_hat.webp
# Witch’s Hat added!
# ✅ Downloaded: heart_balloon.webp
# Heart Balloon added!
# ✅ Downloaded: headband.webp
# Headband added!
# ✅ Downloaded: human_scull.webp
# Human Scull added!
# ✅ Downloaded: lips.webp
# Lips added!
# ✅ Downloaded: bouquet.webp
# Bouquet added!
# ✅ Downloaded: easter_bunny.webp
# Easter Bunny added!
# ✅ Downloaded: fish_skeleton.webp
# Fish Skeleton added!
# ✅ Downloaded: tulip_bloom.webp
# Tulip Bloom added!
# ✅ Downloaded: little_cupid.webp
# Little Cupid added!
# ✅ Downloaded: dollar_graffiti.webp
# Dollar Graffiti added!
# ✅ Downloaded: beetle.webp
# Beetle added!
# ✅ Downloaded: head_scarf.webp
# Head Scarf added!
# ✅ Downloaded: heart_box.webp
# Heart Box added!
# ✅ Downloaded: mining_helmet.webp
# Mining Helmet added!
# ✅ Downloaded: spicy_chilli.webp
# Spicy Chilli added!
# ✅ Downloaded: high_hat.webp
# High Hat added!
# ✅ Downloaded: flirty_message.webp
# Flirty Message added!
# ✅ Downloaded: heart_donut.webp
# Heart Donut added!
# ✅ Downloaded: amour_scoops.webp
# Amour Scoops added!
# ✅ Downloaded: boombox.webp
# Boombox added!
# ✅ Downloaded: peaked_cap.webp
# Peaked Cap added!
# ✅ Downloaded: kitty_cat.webp
# Kitty Cat added!
# ✅ Downloaded: broken_heart.webp
# Broken Heart added!
# ✅ Downloaded: heart_shades.webp
# Heart Shades added!
# ✅ Downloaded: party_popper.webp
# Party Popper added!
# ✅ Downloaded: teddy_bear.webp
# Teddy Bear added!
# ✅ Downloaded: westside_hand.webp
# Westside Hand added!
# ✅ Downloaded: love_bell.webp
# Love Bell added!
# ✅ Downloaded: battle_axe.webp
# Battle Axe added!
# ✅ Downloaded: fluffy_wolf.webp
# Fluffy Wolf added!
# ✅ Downloaded: date_pin.webp
# Date Pin added!
# ✅ Downloaded: heart_ring.webp
# Heart Ring added!
# ✅ Downloaded: straw_hat.webp
# Straw Hat added!
# ✅ Downloaded: birthday_cake.webp
# Birthday Cake added!
# ✅ Downloaded: yin_yang.webp
# Yin-Yang added!
# ✅ Downloaded: loving_heart.webp
# Loving Heart added!
# ✅ Downloaded: napkins.webp
# Napkins added!
# ✅ Downloaded: kashket.webp
# Kashket added!
# ✅ Downloaded: pirate_hat.webp
# Pirate Hat added!
# ✅ Downloaded: chef_hat.webp
# Chef Hat added!
# ✅ Downloaded: paper_lantern.webp
# Paper Lantern added!
# ✅ Downloaded: astronaut.webp
# Astronaut added!
# ✅ Downloaded: clubs.webp
# Clubs added!
# ✅ Downloaded: glasses.webp
# Glasses added!
# ✅ Downloaded: bobble_hat.webp
# Bobble Hat added!
# ✅ Downloaded: bubbles.webp
# Bubbles added!
# ✅ Downloaded: double_axe.webp
# Double Axe added!
# ✅ Downloaded: lion_king.webp
# Lion King added!
# ✅ Downloaded: chili.webp
# Chili added!
# ✅ Downloaded: lemon.webp
# Lemon added!
# ✅ Downloaded: hersir.webp
# Hersir added!
# ✅ Downloaded: horned_helm.webp
# Horned Helm added!
# ✅ Downloaded: banana.webp
# Banana added!
# ✅ Downloaded: snail.webp
# Snail added!
# ✅ Downloaded: calendula.webp
# Calendula added!
# ✅ Downloaded: cute_bear.webp
# Cute Bear added!
# ✅ Downloaded: love_candy.webp
# Love Candy added!
# ✅ Downloaded: lily_bloom.webp
# Lily Bloom added!
# ✅ Downloaded: cupid_s_arrow.webp
# Cupid’s Arrow added!
# ✅ Downloaded: grenade.webp
# Grenade added!
# ✅ Downloaded: viking.webp
# Viking added!
# ✅ Downloaded: kitsune_mask.webp
# Kitsune Mask added!
# ✅ Downloaded: mailbox.webp
# Mailbox added!
# ✅ Downloaded: cobra.webp
# Cobra added!
# ✅ Downloaded: padlock.webp
# Padlock added!
# ✅ Downloaded: boat.webp
# Boat added!
# ✅ Downloaded: trophy.webp
# Trophy added!
# ✅ Downloaded: peace_dove.webp
# Peace Dove added!
# ✅ Downloaded: war_bonnet.webp
# War Bonnet added!
# ✅ Downloaded: duck_face.webp
# Duck Face added!
# ✅ Downloaded: handset.webp
# Handset added!
# ✅ Downloaded: keffiyeh.webp
# Keffiyeh added!
# ✅ Downloaded: axe.webp
# Axe added!
# ✅ Downloaded: chick.webp
# Chick added!
# ✅ Downloaded: flag.webp
# Flag added!
# ✅ Downloaded: lovely_kiss.webp
# Lovely Kiss added!
# ✅ Downloaded: ramen.webp
# Ramen added!
# ✅ Downloaded: seahorse.webp
# Seahorse added!
# ✅ Downloaded: polar_bear.webp
# Polar Bear added!
# ✅ Downloaded: pineapple.webp
# Pineapple added!
# ✅ Downloaded: clover.webp
# Clover added!
# ✅ Downloaded: sun_lion.webp
# Sun Lion added!
# ✅ Downloaded: wine_toast.webp
# Wine Toast added!
# ✅ Downloaded: handcuffs.webp
# Handcuffs added!
# ✅ Downloaded: balloon.webp
# Balloon added!
# ✅ Downloaded: loveberry.webp
# Loveberry added!
# ✅ Downloaded: two_katanas.webp
# Two Katanas added!
# ✅ Downloaded: visor.webp
# Visor added!
# ✅ Downloaded: crab.webp
# Crab added!
# ✅ Downloaded: lion_head.webp
# Lion Head added!
# ✅ Downloaded: arabian_horse.webp
# Arabian Horse added!
# ✅ Downloaded: iron_helmet.webp
# Iron Helmet added!
# ✅ Downloaded: angel.webp
# Angel added!
# ✅ Downloaded: easter_egg.webp
# Easter Egg added!
# ✅ Downloaded: jester_hat.webp
# Jester Hat added!
# ✅ Downloaded: plum.webp
# Plum added!
# ✅ Downloaded: banner.webp
# Banner added!
# ✅ Downloaded: mountain_lion.webp
# Mountain Lion added!
# ✅ Downloaded: propeller_cap.webp
# Propeller Cap added!
# ✅ Downloaded: bobby_helmet.webp
# Bobby Helmet added!
# ✅ Downloaded: police_hat.webp
# Police Hat added!
# ✅ Downloaded: inguz_rune.webp
# Inguz Rune added!
# ✅ Downloaded: moon_eagle.webp
# Moon Eagle added!
# ✅ Downloaded: stocking.webp
# Stocking added!
# ✅ Downloaded: jo_rmungandr.webp
# Jörmungandr added!
# ✅ Downloaded: shuriken.webp
# Shuriken added!
# ✅ Downloaded: winter_hat.webp
# Winter Hat added!
# ✅ Downloaded: cherry.webp
# Cherry added!
# ✅ Downloaded: angelic_heart.webp
# Angelic Heart added!
# ✅ Downloaded: flaming_heart.webp
# Flaming Heart added!
# ✅ Downloaded: avocado.webp
# Avocado added!
# ✅ Downloaded: paper_crane.webp
# Paper Crane added!
# ✅ Downloaded: star_crown.webp
# Star Crown added!
# ✅ Downloaded: dragonfly.webp
# Dragonfly added!
# ✅ Downloaded: hamburger.webp
# Hamburger added!
# ✅ Downloaded: police_badge.webp
# Police Badge added!
# ✅ Downloaded: geisha_fan.webp
# Geisha Fan added!
# ✅ Downloaded: kudu_totem.webp
# Kudu Totem added!
# ✅ Downloaded: serpent.webp
# Serpent added!
# ✅ Downloaded: scarab.webp
# Scarab added!
# ✅ Downloaded: mask.webp
# Mask added!
# ✅ Downloaded: pierced_heart.webp
# Pierced Heart added!
# ✅ Downloaded: coffee_bean.webp
# Coffee Bean added!
# ✅ Downloaded: winged_helm.webp
# Winged Helm added!
# ✅ Downloaded: croissant.webp
# Croissant added!
# ✅ Downloaded: koala.webp
# Koala added!
# ✅ Downloaded: moon_face.webp
# Moon Face added!
# ✅ Downloaded: sea_horse.webp
# Sea Horse added!
# ✅ Downloaded: hammerhead.webp
# Hammerhead added!
# ✅ Downloaded: tic_tac_toe.webp
# Tic-Tac-Toe added!
# ✅ Downloaded: anthurium.webp
# Anthurium added!
# ✅ Downloaded: lavender.webp
# Lavender added!
# ✅ Downloaded: lovely_rain.webp
# Lovely Rain added!
# ✅ Downloaded: water_drops.webp
# Water Drops added!
# ✅ Downloaded: unicorn.webp
# Unicorn added!
# ✅ Downloaded: daisy.webp
# Daisy added!
# ✅ Downloaded: romantic_cake.webp
# Romantic Cake added!
# ✅ Downloaded: hot_matcha.webp
# Hot Matcha added!
# ✅ Downloaded: acorn.webp
# Acorn added!
# ✅ Downloaded: ladybug.webp
# Ladybug added!
# ✅ Downloaded: bell_pepper.webp
# Bell Pepper added!
# ✅ Downloaded: neko_mask.webp
# Neko Mask added!
# ✅ Downloaded: baphomet.webp
# Baphomet added!
# ✅ Downloaded: inca_sun.webp
# Inca Sun added!
# ✅ Downloaded: fireman_hat.webp
# Fireman Hat added!
# ✅ Downloaded: sailor_hat.webp
# Sailor Hat added!
# ✅ Downloaded: winged_helmet.webp
# Winged Helmet added!
# ✅ Downloaded: key.webp
# Key added!
# ✅ Downloaded: rhino_warrior.webp
# Rhino Warrior added!
# ✅ Downloaded: toy_bucket.webp
# Toy Bucket added!
# ✅ Downloaded: earflap_hat.webp
# Earflap Hat added!
# ✅ Downloaded: flower_tulip.webp
# Flower Tulip added!
# ✅ Downloaded: flying_dragon.webp
# Flying Dragon added!
# ✅ Downloaded: heart.webp
# Heart added!
# ✅ Downloaded: the_eye.webp
# The Eye added!
# ✅ Downloaded: oak_leaf.webp
# Oak Leaf added!
# ✅ Downloaded: bearskin.webp
# Bearskin added!
# ✅ Downloaded: lion_of_babylon.webp
# Lion of Babylon added!
# ✅ Downloaded: sushi_rolls.webp
# Sushi Rolls added!
# ✅ Downloaded: mayan_moth.webp
# Mayan Moth added!
# ✅ Downloaded: rooster.webp
# Rooster added!
# ✅ Downloaded: owl.webp
# Owl added!
# ✅ Downloaded: sun_mountain.webp
# Sun Mountain added!
# ✅ Downloaded: nemes.webp
# Nemes added!
# ✅ Downloaded: fried_egg.webp
# Fried Egg added!
# ✅ Downloaded: eagle.webp
# Eagle added!
# ✅ Downloaded: evil_dragon.webp
# Evil Dragon added!
# ✅ Downloaded: magic_hat.webp
# Magic Hat added!
# ✅ Downloaded: tie.webp
# Tie added!
# ✅ Downloaded: coconut.webp
# Coconut added!
# ✅ Downloaded: robin_hood.webp
# Robin Hood added!
# ✅ Downloaded: alert_serpent.webp
# Alert Serpent added!
# ✅ Downloaded: silver_ibis.webp
# Silver Ibis added!
# ✅ Downloaded: sleepy_unicorn.webp
# Sleepy Unicorn added!
# ✅ Downloaded: chili_pepper.webp
# Chili Pepper added!
# ✅ Downloaded: gamepad.webp
# Gamepad added!
# ✅ Downloaded: ice_cream.webp
# Ice Cream added!
# ✅ Downloaded: bamboo.webp
# Bamboo added!
# ✅ Downloaded: bascinet.webp
# Bascinet added!
# ✅ Downloaded: rudolph.webp
# Rudolph added!
# ✅ Downloaded: egg_basket.webp
# Egg Basket added!
# ✅ Downloaded: cheese.webp
# Cheese added!
# ✅ Downloaded: origami.webp
# Origami added!
# ✅ Downloaded: palette.webp
# Palette added!
# ✅ Downloaded: skull.webp
# Skull added!
# ✅ Downloaded: tree_of_life.webp
# Tree of Life added!
# ✅ Downloaded: pickaxe.webp
# Pickaxe added!
# ✅ Downloaded: beret.webp
# Beret added!
# ✅ Downloaded: octopus.webp
# Octopus added!
# ✅ Downloaded: sea_dragon.webp
# Sea Dragon added!
# ✅ Downloaded: flower_sun.webp
# Flower Sun added!
# ✅ Downloaded: genie_lamp.webp
# Genie Lamp added!
# ✅ Downloaded: tooth.webp
# Tooth added!
# ✅ Downloaded: bull_of_heaven.webp
# Bull of Heaven added!
# ✅ Downloaded: paw_print.webp
# Paw Print added!
# ✅ Downloaded: burger.webp
# Burger added!
# ✅ Downloaded: deerstalker.webp
# Deerstalker added!
# ✅ Downloaded: fez.webp
# Fez added!
# ✅ Downloaded: old_candle.webp
# Old Candle added!
# ✅ Downloaded: pizza_slice.webp
# Pizza Slice added!
# ✅ Downloaded: telescope.webp
# Telescope added!
# ✅ Downloaded: bandana.webp
# Bandana added!
# ✅ Downloaded: cat_mask.webp
# Cat Mask added!
# ✅ Downloaded: moose_head.webp
# Moose Head added!
# ✅ Downloaded: shako.webp
# Shako added!
# ✅ Downloaded: toilet.webp
# Toilet added!
# ✅ Downloaded: all_seeing_eye.webp
# All-Seeing Eye added!
# ✅ Downloaded: beanie.webp
# Beanie added!
# ✅ Downloaded: conch.webp
# Conch added!
# ✅ Downloaded: cowboy_hat.webp
# Cowboy Hat added!
# ✅ Downloaded: crusader.webp
# Crusader added!
# ✅ Downloaded: diamond.webp
# Diamond added!
# ✅ Downloaded: dolphin.webp
# Dolphin added!
# ✅ Downloaded: flipper.webp
# Flipper added!
# ✅ Downloaded: mannaz_rune.webp
# Mannaz Rune added!
# ✅ Downloaded: oculus.webp
# Oculus added!
# ✅ Downloaded: party_hat.webp
# Party Hat added!
# ✅ Downloaded: phoenix.webp
# Phoenix added!
# ✅ Downloaded: scorpion.webp
# Scorpion added!
# ✅ Downloaded: calm_wolf.webp
# Calm Wolf added!
# ✅ Downloaded: porrige.webp
# Porrige added!
# ✅ Downloaded: flamingo.webp
# Flamingo added!
# ✅ Downloaded: hermit_shell.webp
# Hermit Shell added!
# ✅ Downloaded: knight.webp
# Knight added!
# ✅ Downloaded: pomegranate.webp
# Pomegranate added!
# ✅ Downloaded: garden_pot.webp
# Garden Pot added!
# ✅ Downloaded: mountain_goat.webp
# Mountain Goat added!
# ✅ Downloaded: wreath.webp
# Wreath added!
# ✅ Downloaded: festive_wreath.webp
# Festive Wreath added!
# ✅ Downloaded: ball.webp
# Ball added!
# ✅ Downloaded: bowler_hat.webp
# Bowler Hat added!
# ✅ Downloaded: pumpkin_coach.webp
# Pumpkin Coach added!
# ✅ Downloaded: shortsword.webp
# Shortsword added!
# ✅ Downloaded: spider.webp
# Spider added!
# ✅ Downloaded: cow_skull.webp
# Cow Skull added!
# ✅ Downloaded: trickster_fox.webp
# Trickster Fox added!
# ✅ Downloaded: neptune.webp
# Neptune added!
# ✅ Downloaded: turtle.webp
# Turtle added!
# ✅ Downloaded: flower.webp
# Flower added!
# ✅ Downloaded: legionary.webp
# Legionary added!
# ✅ Downloaded: watching_sun.webp
# Watching Sun added!
# ✅ Downloaded: planet.webp
# Planet added!
# ✅ Downloaded: wasp.webp
# Wasp added!
# ✅ Downloaded: tetsubin.webp
# Tetsubin added!
# ✅ Downloaded: melon.webp
# Melon added!
# ✅ Downloaded: turkey.webp
# Turkey added!
# ✅ Downloaded: pearl.webp
# Pearl added!
# ✅ Downloaded: horseshoe.webp
# Horseshoe added!
# ✅ Downloaded: ancient_urn.webp
# Ancient Urn added!
# ✅ Downloaded: apple.webp
# Apple added!
# ✅ Downloaded: celtic_wolf.webp
# Celtic Wolf added!
# ✅ Downloaded: narcissus.webp
# Narcissus added!
# ✅ Downloaded: leprechaun.webp
# Leprechaun added!
# ✅ Downloaded: monarch.webp
# Monarch added!
# ✅ Downloaded: spanner.webp
# Spanner added!
# ✅ Downloaded: feather.webp
# Feather added!
# ✅ Downloaded: golden_scarab.webp
# Golden Scarab added!
# ✅ Downloaded: monstera.webp
# Monstera added!
# ✅ Downloaded: plume.webp
# Plume added!
# ✅ Downloaded: shinto_shrine.webp
# Shinto Shrine added!
# ✅ Downloaded: viking_shield.webp
# Viking Shield added!
# ✅ Downloaded: thief.webp
# Thief added!
# ✅ Downloaded: hedgehog.webp
# Hedgehog added!
# ✅ Downloaded: wontons.webp
# Wontons added!
# ✅ Downloaded: blood_drop.webp
# Blood Drop added!
# ✅ Downloaded: firebird.webp
# Firebird added!
# ✅ Downloaded: flower_cross.webp
# Flower Cross added!
# ✅ Downloaded: gem.webp
# Gem added!
# ✅ Downloaded: spider_web.webp
# Spider Web added!
# ✅ Downloaded: sunflower.webp
# Sunflower added!
# ✅ Downloaded: gold.webp
# Gold added!
# ✅ Downloaded: rocket.webp
# Rocket added!
# ✅ Downloaded: sparks.webp
# Sparks added!
# ✅ Downloaded: mittens.webp
# Mittens added!
# ✅ Downloaded: tricorne.webp
# Tricorne added!
# ✅ Downloaded: doghouse.webp
# Doghouse added!
# ✅ Downloaded: heater_shield.webp
# Heater Shield added!
# ✅ Downloaded: cake.webp
# Cake added!
# ✅ Downloaded: flytrap.webp
# Flytrap added!
# ✅ Downloaded: sharp_sword.webp
# Sharp Sword added!
# ✅ Downloaded: bonsai.webp
# Bonsai added!
# ✅ Downloaded: tulip.webp
# Tulip added!
# ✅ Downloaded: car.webp
# Car added!
# ✅ Downloaded: nordic_wolf.webp
# Nordic Wolf added!
# ✅ Downloaded: khinkali.webp
# Khinkali added!
# ✅ Downloaded: tiki_mask.webp
# Tiki Mask added!
# ✅ Downloaded: bandage.webp
# Bandage added!
# ✅ Downloaded: rook.webp
# Rook added!
# ✅ Downloaded: celtic_cross.webp
# Celtic Cross added!
# ✅ Downloaded: bow_tie.webp
# Bow Tie added!
# ✅ Downloaded: eye_of_horus.webp
# Eye of Horus added!
# ✅ Downloaded: doberman.webp
# Doberman added!
# ✅ Downloaded: elf_hat.webp
# Elf Hat added!
# ✅ Downloaded: puzzle.webp
# Puzzle added!
# ✅ Downloaded: cricket_helmet.webp
# Cricket Helmet added!
# ✅ Downloaded: eggplant.webp
# Eggplant added!
# ✅ Downloaded: mushroom.webp
# Mushroom added!
# ✅ Downloaded: candle.webp
# Candle added!
# ✅ Downloaded: pi_ata.webp
# Piñata added!
# ✅ Downloaded: spades.webp
# Spades added!
# ✅ Downloaded: ghost.webp
# Ghost added!
# ✅ Downloaded: red_deer.webp
# Red Deer added!
# ✅ Downloaded: bishop.webp
# Bishop added!
# ✅ Downloaded: wolf_rage.webp
# Wolf Rage added!
# ✅ Downloaded: hot_drink.webp
# Hot Drink added!
# ✅ Downloaded: jewel.webp
# Jewel added!
# ✅ Downloaded: press_hat.webp
# Press Hat added!
# ✅ Downloaded: panty.webp
# Panty added!
# ✅ Downloaded: wizard_hat.webp
# Wizard Hat added!
# ✅ Downloaded: carrot.webp
# Carrot added!
# ✅ Downloaded: fenrir.webp
# Fenrir added!
# ✅ Downloaded: high_heels.webp
# High Heels added!
# ✅ Downloaded: smartphone.webp
# Smartphone added!
# ✅ Downloaded: novus_ordo.webp
# Novus Ordo added!
# ✅ Downloaded: brain.webp
# Brain added!
# ✅ Downloaded: wise_raven.webp
# Wise Raven added!
# ✅ Downloaded: valkyrie.webp
# Valkyrie added!
# ✅ Downloaded: fire.webp
# Fire added!
# ✅ Downloaded: flat_cap.webp
# Flat Cap added!
# ✅ Downloaded: carambola.webp
# Carambola added!
# ✅ Downloaded: snow_angel.webp
# Snow Angel added!
# ✅ Downloaded: teru_b_zu.webp
# Teru Bōzu added!
# ✅ Downloaded: worker_ant.webp
# Worker Ant added!
# ✅ Downloaded: cavalier_hat.webp
# Cavalier Hat added!
# ✅ Downloaded: cone.webp
# Cone added!
# ✅ Downloaded: basketball.webp
# Basketball added!
# ✅ Downloaded: trinity_knot.webp
# Trinity Knot added!
# ✅ Downloaded: bucket_hat.webp
# Bucket Hat added!
# ✅ Downloaded: coin.webp
# Coin added!
# ✅ Downloaded: gingerbread.webp
# Gingerbread added!
# ✅ Downloaded: new_year_s_eve.webp
# New Year’s Eve added!
# ✅ Downloaded: santa_hat.webp
# Santa Hat added!
# ✅ Downloaded: french_fries.webp
# French Fries added!
# ✅ Downloaded: bastet.webp
# Bastet added!
# ✅ Downloaded: money_bag.webp
# Money Bag added!
# ✅ Downloaded: corn.webp
# Corn added!
# ✅ Downloaded: hourglass.webp
# Hourglass added!
# ✅ Downloaded: kitsune.webp
# Kitsune added!
# ✅ Downloaded: light_bulb.webp
# Light Bulb added!
# ✅ Downloaded: manta_ray.webp
# Manta Ray added!
# ✅ Downloaded: oxen_of_fire.webp
# Oxen of Fire added!
# ✅ Downloaded: star.webp
# Star added!
# ✅ Downloaded: thunderbird.webp
# Thunderbird added!
# ✅ Downloaded: twin_peaks.webp
# Twin Peaks added!
# ✅ Downloaded: aztec_totem.webp
# Aztec Totem added!
# ✅ Downloaded: baseball_cap.webp
# Baseball Cap added!
# ✅ Downloaded: coin_purse.webp
# Coin Purse added!
# ✅ Downloaded: crown.webp
# Crown added!
# ✅ Downloaded: divine_falcon.webp
# Divine Falcon added!
# ✅ Downloaded: fedora.webp
# Fedora added!
# ✅ Downloaded: horn.webp
# Horn added!
# ✅ Downloaded: imperial_lion.webp
# Imperial Lion added!
# ✅ Downloaded: obon_lantern.webp
# Obon Lantern added!
# ✅ Downloaded: paw.webp
# Paw added!
# ✅ Downloaded: spring_chick.webp
# Spring Chick added!
# ✅ Downloaded: anchor.webp
# Anchor added!
# ✅ Downloaded: baby_bottle.webp
# Baby Bottle added!
# ✅ Downloaded: bike_helmet.webp
# Bike Helmet added!
# ✅ Downloaded: bone.webp
# Bone added!
# ✅ Downloaded: book.webp
# Book added!
# ✅ Downloaded: bunny_ears.webp
# Bunny Ears added!
# ✅ Downloaded: dagger.webp
# Dagger added!
# ✅ Downloaded: doctor_hat.webp
# Doctor Hat added!
# ✅ Downloaded: hard_hat.webp
# Hard Hat added!
# ✅ Downloaded: hazelnut.webp
# Hazelnut added!
# ✅ Downloaded: hippo.webp
# Hippo added!
# ✅ Downloaded: ink_pen.webp
# Ink Pen added!
# ✅ Downloaded: jumbo_pencil.webp
# Jumbo Pencil added!
# ✅ Downloaded: leaf.webp
# Leaf added!
# ✅ Downloaded: love_lock.webp
# Love Lock added!
# ✅ Downloaded: moto_helmet.webp
# Moto Helmet added!
# ✅ Downloaded: mustache.webp
# Mustache added!
# ✅ Downloaded: mustang.webp
# Mustang added!
# ✅ Downloaded: potion.webp
# Potion added!
# ✅ Downloaded: rose.webp
# Rose added!
# ✅ Downloaded: royal_crown.webp
# Royal Crown added!
# ✅ Downloaded: sakura.webp
# Sakura added!
# ✅ Downloaded: sauron.webp
# Sauron added!
# ✅ Downloaded: scissors.webp
# Scissors added!
# ✅ Downloaded: strawberry.webp
# Strawberry added!
# ✅ Downloaded: turban.webp
# Turban added!
# ✅ Downloaded: twin_koi.webp
# Twin Koi added!
# ✅ Downloaded: unicorn_head.webp
# Unicorn Head added!
# ✅ Downloaded: moon_cross.webp
# Moon Cross added!
# ✅ Downloaded: pirate_scull.webp
# Pirate Scull added!
# ✅ Downloaded: toilet_paper.webp
# Toilet Paper added!
# ✅ Downloaded: bubble_tea.webp
# Bubble Tea added!
# ✅ Downloaded: morgenstern.webp
# Morgenstern added!
# ✅ Downloaded: pencil.webp
# Pencil added!
# ✅ Downloaded: fleur_de_lis.webp
# Fleur-de-lis added!
# ✅ Downloaded: ring.webp
# Ring added!
# ✅ Downloaded: shell.webp
# Shell added!
# ✅ Downloaded: ram_of_amun.webp
# Ram of Amun added!
# ✅ Downloaded: bread.webp
# Bread added!
# ✅ Downloaded: okami_wolf.webp
# Okami Wolf added!
# ✅ Downloaded: pyramid.webp
# Pyramid added!
# ✅ Downloaded: jingle_bell.webp
# Jingle Bell added!
# ✅ Downloaded: mistletoe.webp
# Mistletoe added!
# ✅ Downloaded: ornament.webp
# Ornament added!
# ✅ Downloaded: greek_helmet.webp
# Greek Helmet added!
# ✅ Downloaded: coonskin_cap.webp
# Coonskin Cap added!
# ✅ Downloaded: crescent.webp
# Crescent added!
# ✅ Downloaded: cactus_bloom.webp
# Cactus Bloom added!
# ✅ Downloaded: muffin.webp
# Muffin added!
# ✅ Downloaded: fuchsia.webp
# Fuchsia added!
# ✅ Downloaded: two_hearts.webp
# Two Hearts added!
# ✅ Downloaded: la_corona.webp
# La Corona added!
# ✅ Downloaded: tamagotchi.webp
# Tamagotchi added!
# ✅ Downloaded: chest.webp
# Chest added!
# ✅ Downloaded: gua_pi_mao.webp
# Gua Pi Mao added!
# ✅ Downloaded: illuminati.webp
# Illuminati added!
# ✅ Downloaded: nigiri.webp
# Nigiri added!
# ✅ Downloaded: musical_note.webp
# Musical Note added!
# ✅ Downloaded: shooting_star.webp
# Shooting Star added!
# ✅ Downloaded: sword_fight.webp
# Sword Fight added!
# ✅ Downloaded: maple.webp
# Maple added!
# ✅ Downloaded: fishing_hook.webp
# Fishing Hook added!
# ✅ Downloaded: alarm.webp
# Alarm added!
# ✅ Downloaded: meat_leg.webp
# Meat Leg added!
# ✅ Downloaded: jellyfish.webp
# Jellyfish added!
# ✅ Downloaded: vortex.webp
# Vortex added!
# ✅ Downloaded: cicada.webp
# Cicada added!
# ✅ Downloaded: bowtie.webp
# Bowtie added!
# ✅ Downloaded: donut.webp
# Donut added!
# ✅ Downloaded: cunning_fox.webp
# Cunning Fox added!
# ✅ Downloaded: arcane_mirror.webp
# Arcane Mirror added!
# ✅ Downloaded: grape.webp
# Grape added!
# ✅ Downloaded: watermelon.webp
# Watermelon added!
# ✅ Downloaded: spirit_impala.webp
# Spirit Impala added!
# ✅ Downloaded: sombrero.webp
# Sombrero added!
# ✅ Downloaded: tribal_shield.webp
# Tribal Shield added!
# ✅ Downloaded: jolly_roger.webp
# Jolly Roger added!
# ✅ Downloaded: pear.webp
# Pear added!
# ✅ Downloaded: pegasus.webp
# Pegasus added!
# ✅ Downloaded: eikthyrnir.webp
# Eikthyrnir added!
# ✅ Downloaded: moon.webp
# Moon added!
# ✅ Downloaded: shield.webp
# Shield added!
# ✅ Downloaded: thor_hammer.webp
# Thor Hammer added!
# ✅ Downloaded: wagasa.webp
# Wagasa added!
# ✅ Downloaded: crusader_cross.webp
# Crusader Cross added!
# ✅ Downloaded: sea_jelly.webp
# Sea Jelly added!
# ✅ Downloaded: drug.webp
# Drug added!
# ✅ Downloaded: pawn.webp
# Pawn added!
# ✅ Downloaded: cookie.webp
# Cookie added!
# ✅ Downloaded: fireworks.webp
# Fireworks added!
# ✅ Downloaded: ice_pop.webp
# Ice Pop added!
# ✅ Downloaded: greek_sun.webp
# Greek Sun added!
# ✅ Downloaded: holy_grail.webp
# Holy Grail added!
# ✅ Downloaded: takoyaki.webp
# Takoyaki added!
# ✅ Downloaded: crystal.webp
# Crystal added!
# ✅ Downloaded: lightning.webp
# Lightning added!
# ✅ Downloaded: sprout.webp
# Sprout added!
# ✅ Downloaded: steampunk_hat.webp
# Steampunk Hat added!
# ✅ Downloaded: white_deer.webp
# White Deer added!
# ✅ Downloaded: candy.webp
# Candy added!
# ✅ Downloaded: love_letter.webp
# Love Letter added!
# ✅ Downloaded: conical_hat.webp
# Conical Hat added!
# ✅ Downloaded: fish.webp
# Fish added!
# ✅ Downloaded: academic_cap.webp
# Academic Cap added!
# ✅ Downloaded: magic_wand.webp
# Magic Wand added!
# ✅ Downloaded: dice.webp
# Dice added!
# ✅ Downloaded: elephant.webp
# Elephant added!
# ✅ Downloaded: sun.webp
# Sun added!
# ✅ Downloaded: top_hat.webp
# Top Hat added!
# ✅ Downloaded: breeze.webp
# Breeze added!
# ✅ Downloaded: cocktail.webp
# Cocktail added!
# ✅ Downloaded: kite.webp
# Kite added!
# ✅ Downloaded: mafdet.webp
# Mafdet added!
# ✅ Downloaded: cupcake.webp
# Cupcake added!
# ✅ Downloaded: gift_box.webp
# Gift Box added!
# ✅ Downloaded: bug.webp
# Bug added!
# ✅ Downloaded: guitar.webp
# Guitar added!
# ✅ Downloaded: magic_vial.webp
# Magic Vial added!
# ✅ Downloaded: like.webp
# Like added!
# ✅ Downloaded: piranha.webp
# Piranha added!
# ✅ Downloaded: ribeye_steak.webp
# Ribeye Steak added!
# ✅ Downloaded: beer.webp
# Beer added!
# ✅ Downloaded: lemon_slice.webp
# Lemon Slice added!
# ✅ Downloaded: maple_leaf.webp
# Maple Leaf added!
# ✅ Downloaded: totem_bear.webp
# Totem Bear added!
# ✅ Downloaded: snowflake.webp
# Snowflake added!
# ✅ Downloaded: pilot_hat.webp
# Pilot Hat added!
# ✅ Downloaded: earth.webp
# Earth added!
# ✅ Downloaded: tsunami.webp
# Tsunami added!
# ✅ Downloaded: onigiri.webp
# Onigiri added!
# ✅ Downloaded: dessert.webp
# Dessert added!
# ✅ Downloaded: war_tiger.webp
# War Tiger added!
# ✅ Downloaded: ufo.webp
# UFO added!
# ✅ Downloaded: aztec_falcon.webp
# Aztec Falcon added!
# ✅ Downloaded: venetian_mask.webp
# Venetian Mask added!
# ✅ Downloaded: crystal_ball.webp
# Crystal Ball added!
# ✅ Downloaded: flashlight.webp
# Flashlight added!
# ✅ Downloaded: rain_drop.webp
# Rain Drop added!
# ✅ Downloaded: cactus.webp
# Cactus added!
# ✅ Downloaded: diamonds.webp
# Diamonds added!
# ✅ Downloaded: bottlenose.webp
# Bottlenose added!
# ✅ Downloaded: bunny.webp
# Bunny added!
# ✅ Downloaded: full_moon.webp
# Full Moon added!
# ✅ Downloaded: hand_of_god.webp
# Hand of God added!
# ✅ Downloaded: pith_helmet.webp
# Pith Helmet added!
# ✅ Downloaded: cash.webp
# Cash added!
# ✅ Downloaded: champagne.webp
# Champagne added!
# ✅ Downloaded: ouroboros.webp
# Ouroboros added!
# ✅ Downloaded: coat_of_arms.webp
# Coat of Arms added!
# ✅ Downloaded: gear.webp
# Gear added!
# ✅ Downloaded: alkonost.webp
# Alkonost added!
# ✅ Downloaded: christmas_tree.webp
# Christmas Tree added!
# ✅ Downloaded: ice_skates.webp
# Ice Skates added!
# ✅ Downloaded: lotus_flower.webp
# Lotus Flower added!
# ✅ Downloaded: galaxy.webp
# Galaxy added!
# ✅ Downloaded: royal_turban.webp
# Royal Turban added!
# ✅ Downloaded: sword.webp
# Sword added!
# ✅ Downloaded: radar.webp
# Radar added!
# ✅ Downloaded: bottle.webp
# Bottle added!
# ✅ Downloaded: warhorse.webp
# Warhorse added!
# ✅ Downloaded: piggy_bank.webp
# Piggy Bank added!
# ✅ Downloaded: griffon.webp
# Griffon added!
# ✅ Downloaded: sakura_flower.webp
# Sakura Flower added!
# ✅ Downloaded: pc_mouse.webp
# PC Mouse added!
# ✅ Downloaded: nemean_lion.webp
# Nemean Lion added!
# ✅ Downloaded: wepwawet.webp
# Wepwawet added!
# ✅ Downloaded: lily.webp
# Lily added!
# ✅ Downloaded: omusubi.webp
# Omusubi added!
# ✅ Downloaded: fehu_rune.webp
# Fehu Rune added!
# ✅ Downloaded: shark_knife.webp
# Shark Knife added!
# ✅ Downloaded: sumerian_bird.webp
# Sumerian Bird added!
# ✅ Downloaded: heraldic_lily.webp
# Heraldic Lily added!
# ✅ Downloaded: bee.webp
# Bee added!
# ✅ Downloaded: winter_house.webp
# Winter House added!
# ✅ Downloaded: anubis.webp
# Anubis added!
# ✅ Downloaded: cursor.webp
# Cursor added!
# ✅ Downloaded: cap.webp
# Cap added!
# ✅ Downloaded: yogi_shaman.webp
# Yogi Shaman added!
# ✅ Downloaded: egg.webp
# Egg added!
# ✅ Downloaded: paschal_lamb.webp
# Paschal Lamb added!
# ✅ Downloaded: bicorne.webp
# Bicorne added!
# ✅ Downloaded: snowman.webp
# Snowman added!
# ⏭️ Skipped (Already exist): jo_rmungandr.webp
# Joörmungandr added!

# %% [markdown]
# # 4. Parsing backgrounds

# %%
# url of site for parsing
url = "https://telegifter.ru/gifts/rarest-background/"

# %%
# Check access
pages = requests.get(url) # подключаемся
soup = bs(pages.text, 'html.parser') # определеяем
print(pages.status_code)
# Out:
# 200

# %%
# Result list for dataframe in future
result_list_bg = { 
    "background_id": [],
    "background_name": [],
    "background_image_url": []
}

# %%
bg_container = soup.find('div', class_='gifts-table-rare active container')
bg_cards = bg_container.find_all('div', class_='row gift-item')

print(f'📦 Found elements: {len(bg_cards)}')
# Out:
# 📦 Found elements: 80

# %%
images_folder = 'images/bgs'

if not os.path.exists(images_folder):
    os.makedirs(images_folder)
    print(f'✅ Folder created: {images_folder}')
else:
    print(f'📂 Folder is already exist: {images_folder}')
# Out:
# 📂 Folder is already exist: images/bgs

# %%
def extract_gradient_colors(gradient_style):
    """
    Returns: (color_start, color_end) or (None, None)
    """
    if not gradient_style:
        return None, None
    
    try:
        colors = re.findall(r'rgb\((\d+),\s*(\d+),\s*(\d+)\)', gradient_style)
        
        if len(colors) >= 2:
            # First color
            color_start = ','.join(colors[0])  # "54,55,56"
            # Last color
            color_end = ','.join(colors[-1])   # "14,15,15"
            return color_start, color_end
        elif len(colors) == 1:
            color_start = ','.join(colors[0])
            return color_start, color_start
        else:
            return None, None
    except:
        return None, None

# %%
def create_gradient_image(gradient_style, filename, folder, width=1000, height=1000):
    try:
        colors = re.findall(r'rgb\((\d+),\s*(\d+),\s*(\d+)\)', gradient_style)
        
        if len(colors) >= 2:
            color1 = tuple(int(c) for c in colors[0])
            color2 = tuple(int(c) for c in colors[-1])
            
            img = Image.new('RGB', (width, height))
            draw = ImageDraw.Draw(img)
            
            for y in range(height):
                r = int(color1[0] + (color2[0] - color1[0]) * y / height)
                g = int(color1[1] + (color2[1] - color1[1]) * y / height)
                b = int(color1[2] + (color2[2] - color1[2]) * y / height)
                draw.line((0, y, width, y), fill=(r, g, b))
            
            filepath = os.path.join(folder, filename + '.png')
            img.save(filepath, 'PNG')
            print(f'✅ Gradient created: {filename}.png')
            return filepath
        else:
            print(f'⚠️ Color failure {gradient_style}')
            return None
            
    except Exception as e:
        print(f'❌ Error: {e}')
        return None

# %%
i = 0

# %time
for card in bg_cards:
    bg_title = card.find_all('div', class_='col-sm-3 col-xs-6')[1].text.strip()
    print(bg_title)
    
    try:
        rare_elem = card.find_all('div', class_='col-sm-3 col-xs-6')[0].find('div', class_='gifts-table-rare-bg')
        gradient_style = rare_elem.get('style').strip()

        colors = re.findall(r'rgb\((\d+),\s*(\d+),\s*(\d+)\)', gradient_style)

        if len(colors) >= 2:
            color_start = ','.join(colors[0])
            color_end = ','.join(colors[-1])
        elif len(colors) == 1:
            color_start = ','.join(colors[0])
            color_end = color_start
        else:
            color_start = ''
            color_end = ''

        filename = re.sub(r'[^a-zA-Z0-9]', '_', bg_title).lower().strip('_')

        gradient_path = create_gradient_image(gradient_style, filename, images_folder)

        result_list_bg['background_id'].append(i)
        result_list_bg['background_name'].append(bg_title)
        result_list_bg['background_image_url'].append(filename)

        print(f'{i} - {bg_title} added!')
        i += 1
            
    except Exception as e:
        print(f'⚠️ Error {bg_title}: {e}')
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Alkonost
# ⚠️ Error Alkonost: 'NoneType' object has no attribute 'get'
# Christmas Tree
# ⚠️ Error Christmas Tree: 'NoneType' object has no attribute 'get'
# Ice Skates
# ⚠️ Error Ice Skates: 'NoneType' object has no attribute 'get'
# Lotus Flower
# ⚠️ Error Lotus Flower: 'NoneType' object has no attribute 'get'
# Galaxy
# ⚠️ Error Galaxy: 'NoneType' object has no attribute 'get'
# Royal Turban
# ⚠️ Error Royal Turban: 'NoneType' object has no attribute 'get'
# Sword
# ⚠️ Error Sword: 'NoneType' object has no attribute 'get'
# Radar
# ⚠️ Error Radar: 'NoneType' object has no attribute 'get'
# Bottle
# ⚠️ Error Bottle: 'NoneType' object has no attribute 'get'
# Warhorse
# ⚠️ Error Warhorse: 'NoneType' object has no attribute 'get'
# Piggy Bank
# ⚠️ Error Piggy Bank: 'NoneType' object has no attribute 'get'
# Griffon
# ⚠️ Error Griffon: 'NoneType' object has no attribute 'get'
# Sakura Flower
# ⚠️ Error Sakura Flower: 'NoneType' object has no attribute 'get'
# PC Mouse
# ⚠️ Error PC Mouse: 'NoneType' object has no attribute 'get'
# Nemean Lion
# ⚠️ Error Nemean Lion: 'NoneType' object has no attribute 'get'
# Wepwawet
# ⚠️ Error Wepwawet: 'NoneType' object has no attribute 'get'
# Lily
# ⚠️ Error Lily: 'NoneType' object has no attribute 'get'
# Omusubi
# ⚠️ Error Omusubi: 'NoneType' object has no attribute 'get'
# Fehu Rune
# ⚠️ Error Fehu Rune: 'NoneType' object has no attribute 'get'
# Shark Knife
# ⚠️ Error Shark Knife: 'NoneType' object has no attribute 'get'
# Sumerian Bird
# ⚠️ Error Sumerian Bird: 'NoneType' object has no attribute 'get'
# Heraldic Lily
# ⚠️ Error Heraldic Lily: 'NoneType' object has no attribute 'get'
# Bee
# ⚠️ Error Bee: 'NoneType' object has no attribute 'get'
# Winter House
# ⚠️ Error Winter House: 'NoneType' object has no attribute 'get'
# Anubis
# ⚠️ Error Anubis: 'NoneType' object has no attribute 'get'
# Cursor
# ⚠️ Error Cursor: 'NoneType' object has no attribute 'get'
# Cap
# ⚠️ Error Cap: 'NoneType' object has no attribute 'get'
# Yogi Shaman
# ⚠️ Error Yogi Shaman: 'NoneType' object has no attribute 'get'
# Egg
# ⚠️ Error Egg: 'NoneType' object has no attribute 'get'
# Paschal Lamb
# ⚠️ Error Paschal Lamb: 'NoneType' object has no attribute 'get'
# Bicorne
# ⚠️ Error Bicorne: 'NoneType' object has no attribute 'get'
# Snowman
# ⚠️ Error Snowman: 'NoneType' object has no attribute 'get'
# Joörmungandr
# ⚠️ Error Joörmungandr: 'NoneType' object has no attribute 'get'

# %% [markdown]
# # Analisys

# %%
df_collections = pd.DataFrame(data=result_list_collection)
df_symbols = pd.DataFrame(data=result_list_symbol)

# %%
print('*'*35)
print(f'Collections lenght: {len(df_collections)}')
print('-'*35)
print(f'Symbols lenght: {len(df_symbols)}')
print('-'*35)
# Out:
# ***********************************
# Collections lenght: 111
# -----------------------------------
# Symbols lenght: 718
# -----------------------------------
